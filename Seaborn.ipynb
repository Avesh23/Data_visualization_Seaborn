# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
iris =  sns.load_dataset("iris")
planets= sns.load_dataset("planets")
titanic= sns.load_dataset("titanic")
penguins = sns.load_dataset("penguins")
car_crashes = sns.load_dataset("car_crashes")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# LINE PLOT

# %%
sns.lineplot(x="day",y="tip",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# BAR PLOT

# %%
sns.barplot(x="day" ,y="total_bill", hue="sex",data=tips )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day" ,y="total_bill", data=tips ,hue="sex",errorbar=("ci",0))
#plt.legend(title='sex', loc='upper right', bbox_to_anchor=(1, 1))
plt.legend(title='Sex', loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# HISTOGRAM PLOT (HIST)

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=penguins, x="bill_length_mm",y="bill_depth_mm",bins=30)
plt.xlabel("Bill length")
plt.ylabel("Bill Depth")
# Out:
# Text(0, 0.5, 'Bill Depth')

# %%
sns.histplot(data=tips, x="day",hue="sex",palette="GnBu")
plt.xlabel("sex")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# SCATTER PLOT

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip", hue="time",size="size",palette='GnBu')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# HEATMAP

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
gp=tips.groupby("sex").agg({"tip":"mean"})
sns.heatmap(gp)
# Out:
# C:\Users\Hakim\AppData\Local\Temp\ipykernel_1064\2299905550.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gp=tips.groupby("sex").agg({"tip":"mean"})
# <Axes: ylabel='sex'>

# %% [markdown]
# COUNTPLOT

# %%
sns.countplot(data=tips, x="time")
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %% [markdown]
# VIOLINPLOT

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.violinplot(data=tips, x="total_bill")
plt.show()

# %%
sns.violinplot(data=titanic, x="fare")
plt.show()

# %% [markdown]
# PARIPLOT

# %%
sns.pairplot(tips)

# %%
sns.pairplot(titanic)

# %% [markdown]
# STRIPPLOT

# %%
sns.stripplot(data=tips, x= "day", y="total_bill" , hue="sex" , dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# BOXPLOT

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.boxplot(data=tips , x="tip")
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(data=penguins , x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# CATPLOT

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="day" ,y="tip", data=tips,kind ="bar", errorbar=('ci', 0))

# %% [markdown]
# STYLE

# %%
sns.catplot(x="day" ,y="tip", data=tips,kind ="bar", errorbar=('ci', 0))
sns.set_style(style="ticks")

# %% [markdown]
# MULTIPLOT SEABORN

# %%
a = sns.FacetGrid(tips, col="time", hue="sex")
a.map(sns.barplot,"day","tip")
# Out:
# C:\Users\Hakim\AppData\Roaming\Python\Python310\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# RELATIONAL PLOT

# %%
sns.relplot(data=tips,x="tip",y="total_bill",hue="sex",kind="line")

# %% [markdown]
# SWARMPLOT

# %%
sns.swarmplot(data=tips,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# KDEPLOT (KERNEL DENSITY ESTIMATION)

# %%
sns.kdeplot(data=tips,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips,x="tip",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>
